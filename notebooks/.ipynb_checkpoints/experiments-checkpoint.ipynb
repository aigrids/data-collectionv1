# %%
import os
import sys

sys.path.append('../')
sys.path.append('../src')
sys.path.append('../ai4climate')
import configuration
import transformer
import taskdata

PATH_CONFIG = '../config.yml'
PATH_DATA_ROOT = '../../donti_group_shared/AI4Climate/processed/'

# %%
# parse experiment configurations into dictionary
cfg = configuration.ExperimentConfiguration(PATH_CONFIG)

# load task datasets
(
    opfdata_taskdata,
    powergraph_taskdata,
    solarcube_taskdata,
    buildingelectricity_taskdata
) = taskdata.load_all(cfg, PATH_DATA_ROOT)
# Out:
# Running computation on GPU
# All tests for configuration passed!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       2 cfg = configuration.ExperimentConfiguration(PATH_CONFIG)
#       4 # load task datasets
#       5 (
#       6     opfdata_taskdata,
#       7     powergraph_taskdata,
#       8     solarcube_taskdata,
#       9     buildingelectricity_taskdata
# ---> 10 ) = taskdata.load_all(cfg)
#
# TypeError: load_all() missing 1 required positional argument: 'path_data_root'
